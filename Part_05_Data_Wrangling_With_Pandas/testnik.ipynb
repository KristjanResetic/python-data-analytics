# %%
"""Web data Acquisition Pipeline."""

from __future__ import annotations

from pathlib import Path

import pandas as pd

MAIN_DATA_DIR = Path.cwd().parent / "data" / "project"
IP_INFO_CSV = MAIN_DATA_DIR / "ip_info.csv"

ip_meta_data = pd.read_csv(IP_INFO_CSV)

ip_meta_data
# Out:
#                   ip    rir  is_mobile is_crawler  is_datacenter  is_tor  \
# 0     18.118.121.126   ARIN      False      False           True   False
# 1      188.187.129.8   RIPE      False      False          False   False
# 2    217.113.194.141   RIPE      False      False           True   False
# 3     20.169.105.164   ARIN      False      False           True   False
# 4     162.158.162.67   ARIN      False      False           True   False
# ..               ...    ...        ...        ...            ...     ...
# 504     8.219.153.58  APNIC      False      False           True   False
# 505   20.169.104.239   ARIN      False      False           True   False
# 506  188.166.220.242   RIPE      False      False           True   False
# 507     141.98.11.97   RIPE      False      False           True   False
# 508    209.38.81.198   ARIN      False      False           True   False
#
#      is_proxy  is_vpn  is_abuser             datacenter_name  \
# 0        True    True       True    Amazon Technologies Inc.
# 1        True   False       True                         NaN
# 2       False   False       True  L'ile aux surfers s.a.r.l.
# 3        True    True       True             Microsoft Azure
# 4       False   False      False              cloudflare.com
# ..        ...     ...        ...                         ...
# 504     False    True       True                     alibaba
# 505      True    True       True             Microsoft Azure
# 506     False    True       True                DIGITALOCEAN
# 507      True   False       True            LT HOSTBALTIC 11
# 508     False    True       True                DigitalOcean
#
#                                   company_name company_abuser_score  \
# 0                     Amazon Technologies Inc.         0.0006 (Low)
# 1          JSC ER-Telecom Holding Tomsk Branch         0.0059 (Low)
# 2                           FR BABBAR 20220729   0.9922 (Very High)
# 3                        Microsoft Corporation         0.0011 (Low)
# 4                             Cloudflare, Inc.         0.0077 (Low)
# ..                                         ...                  ...
# 504  Alibaba Cloud (Singapore) Private Limited         0.0051 (Low)
# 505                      Microsoft Corporation         0.0011 (Low)
# 506                               DIGITALOCEAN        0.0439 (High)
# 507                           LT HOSTBALTIC 11   0.4648 (Very High)
# 508                          DigitalOcean, LLC        0.0374 (High)
#
#     company_type        country                  city  latitude  longitude
# 0        hosting  United States              Columbus  39.96118  -82.99879
# 1            isp         Russia                 Tomsk  56.50032   84.98204
# 2       business         France  Charleville-Mézières  49.74950    4.60950
# 3            isp  United States               Phoenix  33.44838 -112.07404
# 4        hosting      Singapore             Singapore   1.28967  103.85007
# ..           ...            ...                   ...       ...        ...
# 504      hosting      Singapore             Singapore   1.28967  103.85007
# 505          isp  United States               Phoenix  33.44838 -112.07404
# 506      hosting      Singapore             Singapore   1.28967  103.85007
# 507     business      Lithuania             Panevėžys  55.73330   24.35000
# 508      hosting      Australia                Sydney -33.86785  151.20732
#
# [509 rows x 17 columns]
